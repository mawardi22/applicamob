# %% [markdown]
# <a href="https://colab.research.google.com/github/mawardi22/applicamob/blob/master/F5_TTS_Latest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvcc --version
# https://pytorch.org/get-started/locally/
# pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124

# %%
# !pip install git+https://github.com/SWivid/F5-TTS.git
from IPython.display import clear_output
clear_output()

# %%
# !f5-tts_infer-gradio --share
# Out:
# 2025-07-26 12:33:03.215217: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753533183.459067    2430 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753533183.524998    2430 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-26 12:33:04.049254: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Download Vocos from huggingface charactr/vocos-mel-24khz
# config.yaml: 100% 461/461 [00:00<00:00, 2.84MB/s]
# pytorch_model.bin: 100% 54.4M/54.4M [00:01<00:00, 40.2MB/s]
# model_1250000.safetensors: 100% 1.35G/1.35G [00:07<00:00, 187MB/s]
#
# vocab :  /usr/local/lib/python3.11/dist-packages/f5_tts/infer/examples/vocab.txt
# token :  custom
# model :  /root/.cache/huggingface/hub/models--SWivid--F5-TTS/snapshots/84e5a410d9cead4de2f847e7c9369a6440bdfaca/F5TTS_v1_Base/model_1250000.safetensors
#
# Starting app...
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://90f55de3c1093649f7.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
